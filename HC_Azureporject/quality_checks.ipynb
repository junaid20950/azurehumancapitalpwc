-- %%
SELECT * FROM hcdatabrickspwc.audit.audit_ingestion limit 10

-- %%
SELECT business_date
FROM hcdatabrickspwc.bronze.jobs
ORDER by business_date DESC

-- %%
SELECT business_date, count(*)
FROM hcdatabrickspwc.bronze.jobs
group by business_date

-- %%
SELECT *
FROM hcdatabrickspwc.silver.jobs

-- %%
SELECT attendance_date, is_active
, count(*)
FROM hcdatabrickspwc.silver.attendance
GROUP BY attendance_date, is_active
