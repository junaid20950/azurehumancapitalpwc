-- %%
-- Bronze tables
TRUNCATE TABLE hcdatabrickspwc.bronze.jobs;
TRUNCATE TABLE hcdatabrickspwc.bronze.departments;
TRUNCATE TABLE hcdatabrickspwc.bronze.leaves;
TRUNCATE TABLE hcdatabrickspwc.bronze.attendance;
TRUNCATE TABLE hcdatabrickspwc.bronze.employees;
TRUNCATE TABLE hcdatabrickspwc.bronze.performance_reviews;
TRUNCATE TABLE hcdatabrickspwc.bronze.trainings;
-- Silver tables
TRUNCATE TABLE hcdatabrickspwc.silver.attendance;
TRUNCATE TABLE hcdatabrickspwc.silver.jobs;
TRUNCATE TABLE hcdatabrickspwc.silver.departments;
TRUNCATE TABLE hcdatabrickspwc.silver.employees;
TRUNCATE TABLE hcdatabrickspwc.silver.performance_reviews;
TRUNCATE TABLE hcdatabrickspwc.silver.trainings;
TRUNCATE TABLE hcdatabrickspwc.silver.leaves;

-- Gold tables
TRUNCATE TABLE hcdatabrickspwc.gold.dim_date;
TRUNCATE TABLE hcdatabrickspwc.gold.dim_departments;
TRUNCATE TABLE hcdatabrickspwc.gold.dim_employees;
TRUNCATE TABLE hcdatabrickspwc.gold.fact_job_history;
TRUNCATE TABLE hcdatabrickspwc.gold.salary_agg_by_dept_job;

TRUNCATE TABLE hcdatabrickspwc.audit.audit_ingestion

-- %%
SELECT * FROM hcdatabrickspwc.configs.metadata_config

-- %%
SELECT * FROM hcdatabrickspwc.audit.audit_ingestion
ORDER BY created_at DESC

-- %%
SELECT * FROM hcdatabrickspwc.bronze.jobs

-- %%
RESTORE TABLE hcdatabrickspwc.gold.salary_agg_by_dept_job TO TIMESTAMP AS OF ''

-- %%
DESCRIBE HISTORY hcdatabrickspwc.gold.salary_agg_by_dept_job

-- %%
DESCRIBE EXTENDED hcdatabrickspwc.silver.trainings

-- %%
SHOW CREATE TABLE hcdatabrickspwc.silver.employees

-- %%
SELECT * FROM hcdatabrickspwc.configs.metadata_config

-- %%
SELECT is_active, count(*) FROM hcdatabrickspwc.silver.jobs
GROUP BY is_active

-- %%
SELECT * FROM hcdatabrickspwc.bronze.jobs
WHERE employee_id= 1004

-- %%
SELECT * FROM hcdatabrickspwc.silver.employees
WHERE employee_id= 1003

-- %%
SELECT * FROM hcdatabrickspwc.silver.employees

-- %%
SELECT * FROM hcdatabrickspwc.silver.jobs

-- %%
SELECT * FROM hcdatabrickspwc.silver.jobs

-- %%
SELECT * FROM hcdatabrickspwc.bronze.trainings

-- %%
SELECT * FROM hcdatabrickspwc.gold.salary_agg_by_dept_job

-- %%
SELECT * FROm hcdatabrickspwc.silver.jobs
WHERE is_active = false

-- %%
SELECT * FROM hcdatabrickspwc.gold.salary_agg_by_dept_job WHERE dept_code = 'ADM'

-- %%
SELECT * FROM hcdatabrickspwc.reports.salary_agg_by_dept_job_vw
